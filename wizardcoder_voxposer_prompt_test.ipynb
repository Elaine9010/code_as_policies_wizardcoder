# %%
# This notebook is used to generate answers from the wizardcoder model on the prompts from voxposer

# %%
import os
import sys
import torch
import transformers
from vllm import LLM, SamplingParams


query = "# Query: slide the block to target."
base_model="WizardLM/WizardCoder-Python-7B-V1.0",

llm = LLM(model=base_model, tensor_parallel_size=1)
#load base prompt from txt file in path: prompts/rlbench/composer_prompt.txt
base_prompt = open('prompts/rlbench/composer_prompt.txt', 'r').read()
print(base_prompt)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/.conda/envs/voxposer-env/lib/python3.9/site-packages/transformers/configuration_utils.py:677, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     675 try:
#     676     # Load from local folder or from cache or download from model Hub and cache
# --> 677     resolved_config_file = cached_file(
#     678         pretrained_model_name_or_path,
#     679         configuration_file,
#     680         cache_dir=cache_dir,
#     681         force_download=force_download,
#     682         proxies=proxies,
#     683         resume_download=resume_download,
#     684         local_files_only=local_files_only,
#     685         token=token,
#     686         user_agent=user_agent,
#     687         revision=revision,
#     688         subfolder=subfolder,
# ...

# %%
temperature=0,
max_new_tokens=512,
stop_tokens = ['# Query: ','objects =']
    
sampling_params = SamplingParams(temperature=temperature, top_p=1, max_tokens=max_new_tokens, stop=stop_tokens)
completions = llm.generate(problem_instruction, sampling_params)
for output in completions:
    prompt = output.prompt
    print('==========================question=============================')
    print(prompt)
    generated_text = output.outputs[0].text
    print('===========================answer=============================')
    print(generated_text)
    return generated_text
